# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager as fm
font_path = r"C:\Windows\Fonts\simhei.ttf"  # SimHei 字体路径
my_font = fm.FontProperties(fname=font_path)

a=[131,98,125,131,124,139,131,117,128,108,135,138,131,102,107,114,119,128,121,142,127,130,124,101,110,106,117,110,128,128,115,98,136,126,134,95,138,171,97,8,132,124,113,150,110,117,86,95,144,105,128,130,126,130,126,116,123,106,112,138,123,86,101,99,136,123,117,119,105,137,123,128,85,104,109,134,132,134,156,106,107,127,144,139,139,119,140,83,110,102,123,170,114,105,115,132,145,119,121,122,139,125,138,109,118,132,112,114,122,108,106,123,116,131,127,115,118,112,135,115,143,115,136,118,139,123,112,118,125,109,125,126,114,140,103,130,141,117,106,114,121,114,133,137,92,121,112,145,97,137,105,38,117,122,91,97,153,101,134,106,144,110,137,137,111,104,117,100,111,101,110,105,129,137,112,120,113,133,112,83,94,146]
#设置图形大小
plt.figure(figsize=(20,8),dpi=100)

#计算组距
d=5
num_bins=(max(a)-min(a))//d
# print(num_bins)




plt.hist(a,num_bins,density=True)

plt.grid()
#设置x轴的刻度
plt.xticks(range(min(a),max(a)+d,d))
plt.show()
