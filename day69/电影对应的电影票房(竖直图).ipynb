# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager as fm
font_path = r"C:\Windows\Fonts\simhei.ttf"  # SimHei 字体路径
my_font = fm.FontProperties(fname=font_path)

a=["战狼 2","速度与激情 8","功夫瑜伽","西游伏妖篇","变形金刚 5：\n最后的骑士","爸爸去哪儿 5：\n飞吧，爸爸","加勒比海盗5：\n死无对证","金刚：\n骷髅岛","极限特工：\n终极回归","生化危机 6：\n终章","乘风破浪","神偷奶爸 3","智取威虎山","大闹天竺","英雄归来","悟空传","银河护卫队2","情圣","新木乃伊"]

b=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86]

#设置图像大小
plt.figure(figsize=(20,12),dpi=80)

#绘制条形图
plt.bar(range(len(a)),b)

#设置标签
plt.xticks(range(len(a)),a,fontproperties=my_font,rotation=45)

#添加描述信息
plt.xlabel('电影名称',loc='right',fontproperties=my_font)
plt.ylabel('票房/亿',loc='top',fontproperties=my_font)
plt.title('电影对应的电影票房',fontproperties=my_font)

plt.show()
