# %%
#coding=utf-8
import numpy as np
import matplotlib.pyplot as plt

UK_path='UK_video_data.csv'
US_path='US_video_data.csv'

#加载国家数据
t_us=np.loadtxt(US_path,delimiter=',',dtype=int)
t_uk=np.loadtxt(UK_path,delimiter=',',dtype=int)


#取评论的数据

t_us_comments=t_us[:,-1]
# print(t_us_comments.max(),t_us_comments.min())
#选择比2000小的数据
t_uk_comments=t_us_comments[t_us_comments<=2000]


d=50

bin_nums=(t_us_comments.max()-t_us_comments.min())//d
plt.figure(figsize=(20,10),dpi=100)

plt.hist(t_us_comments,bins=bin_nums)
plt.show()
